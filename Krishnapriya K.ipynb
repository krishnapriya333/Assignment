# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1** . Load the dataset into python environment

# %%
df = pd.read_csv('titanic_dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # **2** .Make passengerid as the index column

# %%
df.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # **3**. Check the basic details of dataset

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # **4**.Fill in all the missing values present in all the columns in the dataset

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df1=df.fillna(df.mean())
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_19104\3725003345.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1=df.fillna(df.mean())

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df1.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df2 = df1.fillna(df.mode().iloc[0])

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # **5**.Check and handle outliers in at least 3 columns in the dataset

# %%
import seaborn as sns

# %%
sns.boxplot(x='Fare',data=df2)
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(x='Age',data=df2)
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x='SibSp',data=df2)
# Out:
# <Axes: xlabel='SibSp'>

# %%
age = df2['Age']
Q1 = age.quantile(0.25)
Q3 = age.quantile(0.75)
IQR = Q3 - Q1
threshold = 1.5
lower_whisker = Q1 -(threshold*IQR)
upper_whisker = Q3 + (threshold*IQR)
df2['Age']=np.where(df2['Age']>upper_whisker,upper_whisker,np.where(df2['Age']<lower_whisker,lower_whisker,df2['Age']))

# %%
sns.boxplot(x='Age',data=df2)
# Out:
# <Axes: xlabel='Age'>

# %%
Fare = df2['Fare']
Q1 = Fare.quantile(0.25)
Q3 = Fare.quantile(0.75)
IQR = Q3 - Q1
threshold = 1.5
lower_whisker = Q1 -(threshold*IQR)
upper_whisker = Q3 + (threshold*IQR)
df2['Fare']=np.where(df2['Fare']>upper_whisker,upper_whisker,np.where(df2['Fare']<lower_whisker,lower_whisker,df2['Fare']))

# %%
sns.boxplot(x='Fare',data=df2)
# Out:
# <Axes: xlabel='Fare'>

# %%
Sibsp = df2['SibSp']
Q1 = Sibsp.quantile(0.25)
Q3 = Sibsp.quantile(0.75)
IQR = Q3 - Q1
threshold = 1.5
lower_whisker = Q1 -(threshold*IQR)
upper_whisker = Q3 + (threshold*IQR)
df2['SibSp']=np.where(df2['SibSp']>upper_whisker,upper_whisker,np.where(df2['SibSp']<lower_whisker,lower_whisker,df2['SibSp']))

# %%
sns.boxplot(x='SibSp',data=df2)
# Out:
# <Axes: xlabel='SibSp'>

# %% [markdown]
# # **6**.Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import MinMaxScaler
df2['target'] = df.Survived

# %%
# Separate features (X) and target variable (y)
X = df2.drop(['Survived','Name','Sex','Ticket','Cabin','Embarked'],axis=1)
Y=df2['Survived']
# Create the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler using the entire dataset
scaler.fit(X)

# We apply the normalization transformation to the entire dataset using transform.
# Apply the scale to the entire dataset
X_normalized = scaler.transform(X)
X_normalized
# Out:
# array([[0.        , 1.        , 0.375     , ..., 0.        , 0.11046037,
#         0.        ],
#        [0.0011236 , 0.        , 0.68269231, ..., 0.        , 1.        ,
#         1.        ],
#        [0.00224719, 1.        , 0.45192308, ..., 0.        , 0.12074461,
#         1.        ],
#        ...,
#        [0.99775281, 1.        , 0.52305995, ..., 0.33333333, 0.35728216,
#         0.        ],
#        [0.9988764 , 0.        , 0.45192308, ..., 0.        , 0.45707739,
#         1.        ],
#        [1.        , 1.        , 0.56730769, ..., 0.        , 0.11807832,
#         0.        ]])

# %%
use_cols = ['Pclass', 'Sex', 'Age', 'Fare', 'SibSp', 'Survived']
result_norm=pd.DataFrame(data=X_normalized).head()

# %%
result_norm
# Out:
#           0    1         2    3    4         5    6
# 0  0.000000  1.0  0.375000  0.4  0.0  0.110460  0.0
# 1  0.001124  0.0  0.682692  0.4  0.0  1.000000  1.0
# 2  0.002247  1.0  0.451923  0.0  0.0  0.120745  1.0
# 3  0.003371  0.0  0.625000  0.4  0.0  0.809027  1.0
# 4  0.004494  1.0  0.625000  0.0  0.0  0.122649  0.0
